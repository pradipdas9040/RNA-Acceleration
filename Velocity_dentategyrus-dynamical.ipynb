# %%
import scvelo as scv
scv.logging.print_version()
# Out:
# Running scvelo 0.2.5 (python 3.10.2) on 2023-05-28 18:05.

# %%
scv.settings.verbosity = 3  # show errors(0), warnings(1), info(2), hints(3)
scv.settings.presenter_view = True  # set max width size for presenter view
scv.set_figure_params('scvelo')  # for beautified visualization

# %%
adata = scv.datasets.dentategyrus()
adata
# Out:
# AnnData object with n_obs × n_vars = 2930 × 13913
#     obs: 'clusters', 'age(days)', 'clusters_enlarged'
#     uns: 'clusters_colors'
#     obsm: 'X_umap'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
scv.pl.proportions(adata)

# %%
scv.pp.filter_genes(adata, min_shared_counts=20)
scv.pp.normalize_per_cell(adata)
scv.pp.filter_genes_dispersion(adata, n_top_genes=2000)
scv.pp.log1p(adata)
# Out:
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 176 genes that are detected 20 counts (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize spliced as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize unspliced as it looks processed already. To enforce normalization, set `enforce=True`.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:01:05) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
scv.tl.recover_dynamics(adata)
# Out:
# recovering dynamics (using 1/8 cores)
#   0%|          | 0/901 [00:00<?, ?gene/s]
#     finished (0:09:28) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)

# %%
scv.tl.velocity(adata, mode='dynamical')
# Out:
# computing velocities
#     finished (0:00:05) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(adata)
# Out:
# computing velocity graph (using 1/8 cores)
#   0%|          | 0/2930 [00:00<?, ?cells/s]
#     finished (0:00:16) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.pl.velocity_embedding(adata, basis = 'umap', arrow_length=3, arrow_size=2, dpi=120)
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding_stream(adata, basis='umap')

# %%
scv.tl.velocity_confidence(adata)
keys = 'velocity_length', 'velocity_confidence'
scv.pl.scatter(adata, c=keys, cmap='coolwarm', perc=[5, 95])
# Out:
# --> added 'velocity_length' (adata.obs)
# --> added 'velocity_confidence' (adata.obs)
# --> added 'velocity_confidence_transition' (adata.obs)

# %%
scv.pl.velocity_graph(adata, threshold=.1)

# %%
adata.uns['neighbors']['distances'] = adata.obsp['distances']
adata.uns['neighbors']['connectivities'] = adata.obsp['connectivities']

scv.tl.paga(adata, groups='clusters')
df = scv.get_df(adata, 'paga/transitions_confidence', precision=2).T
df.style.background_gradient(cmap='Blues').format('{:.2g}')
# Out:
# computing terminal states
# WARNING: Uncertain or fuzzy root cell identification. Please verify.
#     identified 4 regions of root cells and 4 regions of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)
# running PAGA using priors: ['velocity_pseudotime']
#     finished (0:00:02) --> added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns)
#     'paga/transitions_confidence', velocity transitions (adata.uns)
# <style type="text/css">
# #T_c9699_row0_col0, #T_c9699_row0_col1, #T_c9699_row0_col2, #T_c9699_row0_col3, #T_c9699_row0_col4, #T_c9699_row0_col5, #T_c9699_row0_col6, #T_c9699_row0_col7, #T_c9699_row0_col8, #T_c9699_row0_col9, #T_c9699_row0_col10, #T_c9699_row0_col11, #T_c9699_row0_col12, #T_c9699_row0_col13, #T_c9699_row1_col0, #T_c9699_row1_col1, #T_c9699_row1_col2, #T_c9699_row1_col3, #T_c9699_row1_col4, #T_c9699_row1_col5, #T_c9699_row1_col6, #T_c9699_row1_col7, #T_c9699_row1_col8, #T_c9699_row1_col9, #T_c9699_row1_col10, #T_c9699_row1_col11, #T_c9699_row1_col12, #T_c9699_row1_col13, #T_c9699_row2_col0, #T_c9699_row2_col1, #T_c9699_row2_col2, #T_c9699_row2_col3, #T_c9699_row2_col4, #T_c9699_row2_col5, #T_c9699_row2_col6, #T_c9699_row2_col7, #T_c9699_row2_col8, #T_c9699_row2_col9, #T_c9699_row2_col10, #T_c9699_row2_col11, #T_c9699_row2_col12, #T_c9699_row2_col13, #T_c9699_row3_col0, #T_c9699_row3_col1, #T_c9699_row3_col2, #T_c9699_row3_col3, #T_c9699_row3_col4, #T_c9699_row3_col5, #T_c9699_row3_col6, #T_c9699_row3_col7, #T_c9699_row3_col8, #T_c9699_row3_col9, #T_c9699_row3_col10, #T_c9699_row3_col11, #T_c9699_row3_col12, #T_c9699_row3_col13, #T_c9699_row4_col0, #T_c9699_row4_col1, #T_c9699_row4_col2, #T_c9699_row4_col3, #T_c9699_row4_col4, #T_c9699_row4_col6, #T_c9699_row4_col7, #T_c9699_row4_col8, #T_c9699_row4_col9, #T_c9699_row4_col10, #T_c9699_row4_col11, #T_c9699_row4_col12, #T_c9699_row4_col13, #T_c9699_row5_col0, #T_c9699_row5_col1, #T_c9699_row5_col2, #T_c9699_row5_col3, #T_c9699_row5_col4, #T_c9699_row5_col5, #T_c9699_row5_col6, #T_c9699_row5_col7, #T_c9699_row5_col8, #T_c9699_row5_col9, #T_c9699_row5_col10, #T_c9699_row5_col11, #T_c9699_row5_col12, #T_c9699_row5_col13, #T_c9699_row6_col0, #T_c9699_row6_col1, #T_c9699_row6_col2, #T_c9699_row6_col3, #T_c9699_row6_col4, #T_c9699_row6_col6, #T_c9699_row6_col7, #T_c9699_row6_col8, #T_c9699_row6_col9, #T_c9699_row6_col10, #T_c9699_row6_col11, #T_c9699_row6_col12, #T_c9699_row6_col13, #T_c9699_row7_col0, #T_c9699_row7_col1, #T_c9699_row7_col2, #T_c9699_row7_col4, #T_c9699_row7_col5, #T_c9699_row7_col6, #T_c9699_row7_col7, #T_c9699_row7_col8, #T_c9699_row7_col9, #T_c9699_row7_col10, #T_c9699_row7_col11, #T_c9699_row7_col12, #T_c9699_row7_col13, #T_c9699_row8_col0, #T_c9699_row8_col1, #T_c9699_row8_col2, #T_c9699_row8_col3, #T_c9699_row8_col4, #T_c9699_row8_col6, #T_c9699_row8_col7, #T_c9699_row8_col8, #T_c9699_row8_col9, #T_c9699_row8_col10, #T_c9699_row8_col11, #T_c9699_row8_col12, #T_c9699_row8_col13, #T_c9699_row9_col0, #T_c9699_row9_col1, #T_c9699_row9_col2, #T_c9699_row9_col3, #T_c9699_row9_col4, #T_c9699_row9_col6, #T_c9699_row9_col7, #T_c9699_row9_col8, #T_c9699_row9_col9, #T_c9699_row9_col10, #T_c9699_row9_col11, #T_c9699_row9_col12, #T_c9699_row9_col13, #T_c9699_row10_col0, #T_c9699_row10_col1, #T_c9699_row10_col2, #T_c9699_row10_col3, #T_c9699_row10_col4, #T_c9699_row10_col5, #T_c9699_row10_col6, #T_c9699_row10_col7, #T_c9699_row10_col8, #T_c9699_row10_col9, #T_c9699_row10_col10, #T_c9699_row10_col11, #T_c9699_row10_col12, #T_c9699_row10_col13, #T_c9699_row11_col0, #T_c9699_row11_col1, #T_c9699_row11_col2, #T_c9699_row11_col4, #T_c9699_row11_col5, #T_c9699_row11_col6, #T_c9699_row11_col7, #T_c9699_row11_col8, #T_c9699_row11_col9, #T_c9699_row11_col10, #T_c9699_row11_col11, #T_c9699_row11_col12, #T_c9699_row12_col1, #T_c9699_row12_col2, #T_c9699_row12_col3, #T_c9699_row12_col4, #T_c9699_row12_col5, #T_c9699_row12_col6, #T_c9699_row12_col7, #T_c9699_row12_col8, #T_c9699_row12_col9, #T_c9699_row12_col10, #T_c9699_row12_col11, #T_c9699_row12_col12, #T_c9699_row13_col0, #T_c9699_row13_col1, #T_c9699_row13_col2, #T_c9699_row13_col3, #T_c9699_row13_col4, #T_c9699_row13_col5, #T_c9699_row13_col6, #T_c9699_row13_col7, #T_c9699_row13_col8, #T_c9699_row13_col10, #T_c9699_row13_col11, #T_c9699_row13_col12, #T_c9699_row13_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c9699_row4_col5 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_c9699_row6_col5 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_c9699_row7_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_c9699_row8_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_c9699_row9_col5, #T_c9699_row11_col3, #T_c9699_row11_col13, #T_c9699_row12_col0, #T_c9699_row13_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c9699_row12_col13 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c9699">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9699_level0_col0" class="col_heading level0 col0" >Astrocytes</th>
#       <th id="T_c9699_level0_col1" class="col_heading level0 col1" >Cajal Retzius</th>
#       <th id="T_c9699_level0_col2" class="col_heading level0 col2" >Cck-Tox</th>
#       <th id="T_c9699_level0_col3" class="col_heading level0 col3" >Endothelial</th>
#       <th id="T_c9699_level0_col4" class="col_heading level0 col4" >GABA</th>
#       <th id="T_c9699_level0_col5" class="col_heading level0 col5" >Granule immature</th>
#       <th id="T_c9699_level0_col6" class="col_heading level0 col6" >Granule mature</th>
#       <th id="T_c9699_level0_col7" class="col_heading level0 col7" >Microglia</th>
#       <th id="T_c9699_level0_col8" class="col_heading level0 col8" >Mossy</th>
#       <th id="T_c9699_level0_col9" class="col_heading level0 col9" >Neuroblast</th>
#       <th id="T_c9699_level0_col10" class="col_heading level0 col10" >OL</th>
#       <th id="T_c9699_level0_col11" class="col_heading level0 col11" >OPC</th>
#       <th id="T_c9699_level0_col12" class="col_heading level0 col12" >Radial Glia-like</th>
#       <th id="T_c9699_level0_col13" class="col_heading level0 col13" >nIPC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9699_level0_row0" class="row_heading level0 row0" >Astrocytes</th>
#       <td id="T_c9699_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c9699_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c9699_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c9699_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c9699_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c9699_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c9699_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_c9699_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_c9699_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_c9699_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_c9699_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_c9699_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_c9699_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_c9699_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c9699_level0_row1" class="row_heading level0 row1" >Cajal Retzius</th>
#       <td id="T_c9699_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c9699_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c9699_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c9699_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_c9699_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_c9699_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_c9699_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_c9699_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_c9699_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_c9699_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_c9699_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_c9699_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_c9699_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_c9699_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c9699_level0_row2" class="row_heading level0 row2" >Cck-Tox</th>
#       <td id="T_c9699_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_c9699_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_c9699_row2_col2" class="data row2 col2" >0</td>

# %%
scv.pl.paga(adata, basis='umap', size=50, alpha=.1, min_edge_width=2, node_size_scale=1.5)
# Out:
# C:\Users\Pradip\AppData\Roaming\Python\Python310\site-packages\networkx\convert.py:158: DeprecationWarning:
#
# The scipy.sparse array containers will be used instead of matrices
# in Networkx 3.0. Use `from_scipy_sparse_array` instead.
#   return nx.from_scipy_sparse_matrix(data, create_using=create_using)
